# %%
# !sinfo
# !squeue -u $USER
# Out:
# PARTITION     AVAIL  TIMELIMIT  NODES  STATE NODELIST
# gpu-code-test    up    3:00:00      1    mix talon33
# talon*           up 28-00:00:0     10    mix talon[05-06,08,12,18-19,21-24]
# talon*           up 28-00:00:0      5  alloc talon[07,11,13-14,25]
# talon*           up 28-00:00:0      3   idle talon[16-17,20]
# talon-gpu32      up 28-00:00:0      1   mix- talon32
# talon-gpu32      up 28-00:00:0      1  alloc talon35
# talon-large      up 28-00:00:0      2    mix talon[15,36]
# talon-large      up 28-00:00:0      1  alloc talon37
# talon-short      up      30:00      2   idle talon[09-10]
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             266054 talon-lar   OOD_JL emmanuel  R    8:38:25      1 talon15

# %%
# !scontrol show job 266054 | grep -E "NumCPUs|Gres|Mem"
# Out:
#    NumNodes=1 NumCPUs=8 NumTasks=8 CPUs/Task=1 ReqB:S:C:T=0:0:*:*
#    MinCPUsNode=8 MinMemoryNode=128G MinTmpDiskNode=0

# %%
# !sbatch code/run_training.sbatch
# Out:
# sbatch: error: Unable to open file code/run_training.sbatch

# %%
# %%writefile code/run_training.sbatch
# #!/bin/bash
# #SBATCH --job-name=soil_model_training
# #SBATCH --partition=gpu-code-test
# #SBATCH --nodes=1
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=8
# #SBATCH --gres=gpu:1
# #SBATCH --mem=64G
# #SBATCH --time=03:00:00
# #SBATCH --output=results/training_%j.out
# #SBATCH --error=results/training_%j.err
#
# cd "$SLURM_SUBMIT_DIR" || exit 1
#
# echo "Job started on $(hostname) at $(date)"
# echo "Allocated GPUs: $CUDA_VISIBLE_DEVICES"
#
# ray start --head --port=6379 --num-cpus="$SLURM_CPUS_PER_TASK" --num-gpus=1
#
# sleep 5
#
# python code/train.py results/stl_prepared/dataset_prepared_for_training.csv \
#     --outdir results/training \
#     --n_lookback 24 \
#     --epochs 15 \
#     --batch_size 256
#
# ray stop
#
# echo "Job finished at $(date)"
# Out:
# Writing code/run_training.sbatch

# %%
# !ls -la code/run_training.sbatch
# !cat code/run_training.sbatch
# Out:
# -rw-r--r-- 1 emmanuela.andam emmanuela.andam 717 Jul 13 09:52 code/run_training.sbatch
# #!/bin/bash
# #SBATCH --job-name=soil_model_training
# #SBATCH --partition=gpu-code-test
# #SBATCH --nodes=1
# #SBATCH --ntasks=1
# #SBATCH --cpus-per-task=8
# #SBATCH --gres=gpu:1
# #SBATCH --mem=64G
# #SBATCH --time=03:00:00
# #SBATCH --output=results/training_%j.out
# #SBATCH --error=results/training_%j.err
#
# cd "$SLURM_SUBMIT_DIR" || exit 1
#
# echo "Job started on $(hostname) at $(date)"
# echo "Allocated GPUs: $CUDA_VISIBLE_DEVICES"
#
# ray start --head --port=6379 --num-cpus="$SLURM_CPUS_PER_TASK" --num-gpus=1
#
# sleep 5
#
# python code/train.py results/stl_prepared/dataset_prepared_for_training.csv \
#     --outdir results/training \
#     --n_lookback 24 \
#     --epochs 15 \
#     --batch_size 256
#
# ray stop
#
# echo "Job finished at $(date)"

# %%
# !sbatch code/run_training.sbatch
# Out:
# Submitted batch job 266087

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             266087 gpu-code- soil_mod emmanuel  R      14:27      1 talon33
#             266054 talon-lar   OOD_JL emmanuel  R    9:07:29      1 talon15

# %%
# !tail -f results/training_266087.out
# Out:
# 2026-07-13 09:52:42,658	INFO scripts.py:901 -- Next steps
# 2026-07-13 09:52:42,658	INFO scripts.py:904 -- To add another node to this Ray cluster, run
# 2026-07-13 09:52:42,658	INFO scripts.py:907 --   ray start --address='10.228.136.53:6379'
# 2026-07-13 09:52:42,658	INFO scripts.py:916 -- To connect to this Ray cluster:
# 2026-07-13 09:52:42,658	INFO scripts.py:918 -- import ray
# 2026-07-13 09:52:42,658	INFO scripts.py:919 -- ray.init()
# 2026-07-13 09:52:42,658	INFO scripts.py:950 -- To terminate the Ray runtime, run
# 2026-07-13 09:52:42,658	INFO scripts.py:951 --   ray stop
# 2026-07-13 09:52:42,658	INFO scripts.py:954 -- To view the status of the cluster, use
# 2026-07-13 09:52:42,658	INFO scripts.py:955 --   ray status
# ^C

# %%
# !tail -f results/training_266087.out
# Out:
# 2026-07-13 09:52:42,658	INFO scripts.py:901 -- Next steps
# 2026-07-13 09:52:42,658	INFO scripts.py:904 -- To add another node to this Ray cluster, run
# 2026-07-13 09:52:42,658	INFO scripts.py:907 --   ray start --address='10.228.136.53:6379'
# 2026-07-13 09:52:42,658	INFO scripts.py:916 -- To connect to this Ray cluster:
# 2026-07-13 09:52:42,658	INFO scripts.py:918 -- import ray
# 2026-07-13 09:52:42,658	INFO scripts.py:919 -- ray.init()
# 2026-07-13 09:52:42,658	INFO scripts.py:950 -- To terminate the Ray runtime, run
# 2026-07-13 09:52:42,658	INFO scripts.py:951 --   ray stop
# 2026-07-13 09:52:42,658	INFO scripts.py:954 -- To view the status of the cluster, use
# 2026-07-13 09:52:42,658	INFO scripts.py:955 --   ray status
# ^C

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !srun --jobid=266087 nvidia-smi
# Out:
# srun: error: Unable to create step for job 266087: Memory required by task is not available

# %%
# !sstat -j 266087 --format=JobID,MaxRSS,AveCPU,MaxVMSize
# Out:
# JobID            MaxRSS     AveCPU  MaxVMSize
# ------------ ---------- ---------- ----------

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             266087 gpu-code- soil_mod emmanuel  R      27:51      1 talon33
#             266054 talon-lar   OOD_JL emmanuel  R    9:20:53      1 talon15

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#             266087 gpu-code- soil_mod emmanuel  R      27:52      1 talon33
#             266054 talon-lar   OOD_JL emmanuel  R    9:20:54      1 talon15

# %%
# %%writefile code/train.py
"""
Trains all 10 sequence models (LSTM, BiLSTM, GRU, BiGRU, TCN, PatchTST,
Informer, TFT, S4D, Mamba) on the STL-prepared dataset, using Ray to
parallelize training across models. Evaluates each on the reconstructed
raw-scale target (short-term prediction + long-term component) and writes a
results leaderboard.

Usage:
    python train.py results/stl_prepared/dataset_prepared_for_training.csv \
        --outdir results/training --epochs 15 --n_lookback 24

Requires: stl_pipeline.py, dataset.py, models_library.py, s4_model.py,
mamba_model.py all in the same directory (or on PYTHONPATH).
"""

import argparse
import time
from pathlib import Path

import numpy as np
import pandas as pd
import ray
import torch
import torch.nn as nn

from dataset import SoilSequenceDataset, compute_feature_scaler, apply_scaler
from models_library import MODEL_REGISTRY
from s4_model import S4DModel
from mamba_model import MambaModel

TARGET_COLS = [
    "soil_temperature_0_to_7cm",
    "soil_moisture_0_to_7cm",
]

FULL_REGISTRY = dict(MODEL_REGISTRY)
FULL_REGISTRY["S4D"] = S4DModel
FULL_REGISTRY["Mamba"] = MambaModel


def load_prepared(path: str) -> pd.DataFrame:
    df = pd.read_csv(path)
    df["time_utc"] = pd.to_datetime(df["time_utc"])
    return df


def train_one_model(model_cls, train_X, train_y, test_X, n_features, n_targets,
                     epochs, batch_size, lr, device, model_name="model"):
    torch.manual_seed(42)
    model = model_cls(n_features=n_features, n_targets=n_targets).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_X_t = torch.from_numpy(train_X)
    train_y_t = torch.from_numpy(train_y)
    n_train = len(train_X_t)

    model.train()
    history = []
    for epoch in range(epochs):
        perm = torch.randperm(n_train)
        epoch_loss = 0.0
        n_batches = 0
        epoch_start = time.time()
        for i in range(0, n_train, batch_size):
            idx = perm[i:i + batch_size]
            xb = train_X_t[idx].to(device)
            yb = train_y_t[idx].to(device)

            optimizer.zero_grad()
            pred = model(xb)
            loss = loss_fn(pred, yb)

            if torch.isnan(loss):
                print(f"[{model_name}] NaN loss at epoch {epoch}, batch {n_batches} -- stopping early", flush=True)
                history.append({"epoch": epoch, "loss": float("nan")})
                return model, history, True, None

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
            optimizer.step()
            epoch_loss += loss.item()
            n_batches += 1

        avg_loss = epoch_loss / max(n_batches, 1)
        epoch_time = time.time() - epoch_start
        print(f"[{model_name}] epoch {epoch + 1}/{epochs}  loss={avg_loss:.5f}  "
              f"({epoch_time:.1f}s, {n_batches} batches)", flush=True)
        history.append({"epoch": epoch, "loss": avg_loss})

    model.eval()
    with torch.no_grad():
        test_preds = []
        test_X_t = torch.from_numpy(test_X)
        for i in range(0, len(test_X_t), batch_size):
            xb = test_X_t[i:i + batch_size].to(device)
            test_preds.append(model(xb).cpu().numpy())
        test_preds = np.concatenate(test_preds, axis=0)

    return model, history, False, test_preds


def evaluate_reconstructed(test_preds_short, test_long_component, test_raw, target_idx):
    pred_raw = test_preds_short[:, target_idx] + test_long_component
    actual_raw = test_raw

    rmse = float(np.sqrt(np.mean((pred_raw - actual_raw) ** 2)))
    ss_res = np.sum((actual_raw - pred_raw) ** 2)
    ss_tot = np.sum((actual_raw - actual_raw.mean()) ** 2)
    r2 = float(1 - ss_res / ss_tot) if ss_tot > 0 else float("nan")
    return rmse, r2


@ray.remote
def train_and_evaluate_remote(model_name, train_X, train_y, test_X, test_y,
                               n_features, n_targets, epochs, batch_size, lr):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model_cls = FULL_REGISTRY[model_name]

    print(f"[{model_name}] starting on device={device}", flush=True)
    start = time.time()
    model, history, nan_failure, test_preds = train_one_model(
        model_cls, train_X, train_y, test_X, n_features, n_targets,
        epochs, batch_size, lr, device, model_name=model_name,
    )
    elapsed = time.time() - start

    if nan_failure:
        print(f"[{model_name}] FAILED (NaN) after {elapsed:.1f}s", flush=True)
        return {"model": model_name, "status": "nan_failure", "elapsed_s": elapsed,
                "history": history, "test_preds": None}

    print(f"[{model_name}] DONE in {elapsed:.1f}s", flush=True)
    return {"model": model_name, "status": "ok", "elapsed_s": elapsed,
            "history": history, "test_preds": test_preds}


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("prepared_csv", help="Output of stl_pipeline.py")
    parser.add_argument("--outdir", default="./training_out")
    parser.add_argument("--targets", nargs="+", default=TARGET_COLS)
    parser.add_argument("--n_lookback", type=int, default=24)
    parser.add_argument("--epochs", type=int, default=15)
    parser.add_argument("--batch_size", type=int, default=256)
    parser.add_argument("--lr", type=float, default=1e-3)
    parser.add_argument("--models", nargs="+", default=None,
                         help="Subset of models to run (default: all 10)")
    args = parser.parse_args()

    outdir = Path(args.outdir)
    outdir.mkdir(parents=True, exist_ok=True)

    print("Loading prepared dataset...")
    df = load_prepared(args.prepared_csv)

    print(f"Building sliding windows (n_lookback={args.n_lookback})...")
    train_ds = SoilSequenceDataset(df, args.targets, split="train", n_lookback=args.n_lookback)
    test_ds = SoilSequenceDataset(df, args.targets, split="test", n_lookback=args.n_lookback)
    print(f"Train windows: {len(train_ds):,}  |  Test windows: {len(test_ds):,}")

    mean, std = compute_feature_scaler(train_ds)
    apply_scaler(train_ds, mean, std)
    apply_scaler(test_ds, mean, std)

    models_to_run = args.models if args.models else list(FULL_REGISTRY.keys())
    print(f"Training models: {models_to_run}")

    try:
        ray.init(address="auto", ignore_reinit_error=True)
    except ConnectionError:
        print("No Ray cluster found at 'auto' -- falling back to a local Ray instance. "
              "On TALON with a SLURM-launched Ray cluster, this branch shouldn't trigger.")
        ray.init(ignore_reinit_error=True)

    cluster_resources = ray.cluster_resources()
    n_gpus_available = cluster_resources.get("GPU", 0)
    if n_gpus_available > 0:
        gpu_frac = min(1.0, n_gpus_available / max(1, min(len(models_to_run), 4)))
        remote_fn = train_and_evaluate_remote.options(num_gpus=gpu_frac)
        print(f"Ray cluster reports {n_gpus_available} GPU(s) -- "
              f"scheduling each model task with num_gpus={gpu_frac:.2f}")
    else:
        remote_fn = train_and_evaluate_remote
        print("Ray cluster reports 0 GPUs -- running on CPU.")

    futures = [
        remote_fn.remote(
            name, train_ds.X, train_ds.y, test_ds.X, test_ds.y,
            train_ds.n_features, train_ds.n_targets,
            args.epochs, args.batch_size, args.lr,
        )
        for name in models_to_run
    ]

    print(f"\nSubmitted {len(futures)} model training tasks. Waiting for results "
          f"(each will print as it finishes)...\n")

    results = []
    remaining = futures
    while remaining:
        done, remaining = ray.wait(remaining, num_returns=1)
        res = ray.get(done[0])
        results.append(res)
        print(f">>> [{len(results)}/{len(futures)}] {res['model']} finished "
              f"(status={res['status']}, {res['elapsed_s']:.1f}s)\n", flush=True)

    long_components = {c: [] for c in args.targets}
    raw_actuals = {c: [] for c in args.targets}
    group_keys = ["Site", "Latitude", "Longitude"]
    for _, g in df.groupby(group_keys):
        g = g[g["split"] == "test"].sort_values("time_utc")
        if len(g) <= args.n_lookback:
            continue
        for c in args.targets:
            long_components[c].extend(g[f"{c}_long_component"].values[args.n_lookback:])
            raw_actuals[c].extend(g[c].values[args.n_lookback:])

    leaderboard_rows = []
    for res in results:
        if res["status"] == "nan_failure":
            for c in args.targets:
                leaderboard_rows.append({
                    "model": res["model"], "target": c, "status": "nan_failure",
                    "rmse": None, "r2": None, "elapsed_s": res["elapsed_s"],
                })
            continue

        for i, c in enumerate(args.targets):
            long_comp = np.array(long_components[c])
            raw_actual = np.array(raw_actuals[c])
            rmse, r2 = evaluate_reconstructed(res["test_preds"], long_comp, raw_actual, i)
            leaderboard_rows.append({
                "model": res["model"], "target": c, "status": "ok",
                "rmse": rmse, "r2": r2, "elapsed_s": res["elapsed_s"],
            })

    leaderboard = pd.DataFrame(leaderboard_rows)
    leaderboard.to_csv(outdir / "model_leaderboard.csv", index=False)

    print("\n" + "=" * 70)
    print("LEADERBOARD (reconstructed raw-scale metrics)")
    print("=" * 70)
    print(leaderboard.sort_values(["target", "rmse"]).to_string(index=False))
    print(f"\nFull results written to {outdir}/model_leaderboard.csv")


if __name__ == "__main__":
    main()
# Out:
# Overwriting code/train.py

# %%
# !sbatch --wrap="cd \"\$SLURM_SUBMIT_DIR\" && ray start --head --port=6380 --num-cpus=8 --num-gpus=1 && sleep 5 && python code/train.py results/stl_prepared/dataset_prepared_for_training.csv --outdir results/training_quick --n_lookback 24 --epochs 3 --batch_size 512 && ray stop" --partition=talon-gpu32 --gres=gpu:1 --cpus-per-task=8 --mem=64G --time=00:45:00 --job-name=soil_quick --output=results/quick_%j.out --error=results/quick_%j.err
# Out:
# Submitted batch job 266091

# %%
# !tail -f results/quick_266091.out
# Out:
# 2026-07-13 10:33:39,972	INFO scripts.py:901 -- Next steps
# 2026-07-13 10:33:39,972	INFO scripts.py:904 -- To add another node to this Ray cluster, run
# 2026-07-13 10:33:39,972	INFO scripts.py:907 --   ray start --address='10.228.136.52:6380'
# 2026-07-13 10:33:39,973	INFO scripts.py:916 -- To connect to this Ray cluster:
# 2026-07-13 10:33:39,973	INFO scripts.py:918 -- import ray
# 2026-07-13 10:33:39,973	INFO scripts.py:919 -- ray.init()
# 2026-07-13 10:33:39,973	INFO scripts.py:950 -- To terminate the Ray runtime, run
# 2026-07-13 10:33:39,973	INFO scripts.py:951 --   ray stop
# 2026-07-13 10:33:39,973	INFO scripts.py:954 -- To view the status of the cluster, use
# 2026-07-13 10:33:39,973	INFO scripts.py:955 --   ray status
# Loading prepared dataset...
# Building sliding windows (n_lookback=24)...
# Train windows: 2,387,456  |  Test windows: 592,384
# Training models: ['LSTM', 'BiLSTM', 'GRU', 'BiGRU', 'TCN', 'PatchTST', 'Informer', 'TFT', 'S4D', 'Mamba']
# Ray cluster reports 1.0 GPU(s) -- scheduling each model task with num_gpus=0.25
# (train_and_evaluate_remote pid=1061576) [LSTM] starting on device=cuda
# (train_and_evaluate_remote pid=1061574) [BiLSTM] starting on device=cuda
# (train_and_evaluate_remote pid=1061577) [GRU] starting on device=cuda
# (train_and_evaluate_remote pid=1061572) [BiGRU] starting on device=cuda
#
# Submitted 10 model training tasks. Waiting for results (each will print as it finishes)...
#
# (train_and_evaluate_remote pid=1061577) [GRU] epoch 1/3  loss=2.01201  (76.7s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [LSTM] epoch 1/3  loss=1.95497  (97.8s, 4663 batches)
# (train_and_evaluate_remote pid=1061572) [BiGRU] epoch 1/3  loss=1.87352  (123.0s, 4663 batches)
# (train_and_evaluate_remote pid=1061574) [BiLSTM] epoch 1/3  loss=1.83242  (148.6s, 4663 batches)
# (train_and_evaluate_remote pid=1061577) [GRU] epoch 2/3  loss=0.97337  (74.5s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [LSTM] epoch 2/3  loss=0.93833  (95.6s, 4663 batches)
# (train_and_evaluate_remote pid=1061577) [GRU] epoch 3/3  loss=0.72994  (74.6s, 4663 batches)
# >>> [1/10] GRU finished (status=ok, 242.8s)
#
# (train_and_evaluate_remote pid=1061577) [GRU] DONE in 242.8s
# (train_and_evaluate_remote pid=1061577) [TCN] starting on device=cuda
# (train_and_evaluate_remote pid=1061572) [BiGRU] epoch 2/3  loss=0.83902  (121.4s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [LSTM] epoch 3/3  loss=0.67937  (100.7s, 4663 batches)
# (train_and_evaluate_remote pid=1061574) [BiLSTM] epoch 2/3  loss=0.85519  (151.0s, 4663 batches)
# >>> [2/10] LSTM finished (status=ok, 315.0s)
#
# (train_and_evaluate_remote pid=1061576) [LSTM] DONE in 315.0s
# (train_and_evaluate_remote pid=1061576) [PatchTST] starting on device=cuda
# (train_and_evaluate_remote pid=1061577) [TCN] epoch 1/3  loss=1.43148  (138.8s, 4663 batches)
# (train_and_evaluate_remote pid=1061572) [BiGRU] epoch 3/3  loss=0.62554  (134.3s, 4663 batches)
# >>> [3/10] BiGRU finished (status=ok, 401.0s)
#
# (train_and_evaluate_remote pid=1061572) [BiGRU] DONE in 401.0s
# (train_and_evaluate_remote pid=1061572) [Informer] starting on device=cuda
# (train_and_evaluate_remote pid=1061576) [PatchTST] epoch 1/3  loss=1.84914  (116.1s, 4663 batches)
# (train_and_evaluate_remote pid=1061574) [BiLSTM] epoch 3/3  loss=0.59425  (161.1s, 4663 batches)
# >>> [4/10] BiLSTM finished (status=ok, 487.4s)
#
# (train_and_evaluate_remote pid=1061574) [BiLSTM] DONE in 487.4s
# (train_and_evaluate_remote pid=1061574) [TFT] starting on device=cuda
# (train_and_evaluate_remote pid=1061577) [TCN] epoch 2/3  loss=0.85167  (141.6s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [PatchTST] epoch 2/3  loss=1.05111  (113.6s, 4663 batches)
# (train_and_evaluate_remote pid=1061574) [TFT] epoch 1/3  loss=1.99251  (105.0s, 4663 batches)
# (train_and_evaluate_remote pid=1061572) [Informer] epoch 1/3  loss=1.80051  (212.5s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [PatchTST] epoch 3/3  loss=0.85329  (109.3s, 4663 batches)
# >>> [5/10] PatchTST finished (status=ok, 346.3s)
#
# (train_and_evaluate_remote pid=1061576) [PatchTST] DONE in 346.3s
# (train_and_evaluate_remote pid=1061576) [S4D] starting on device=cuda
# (train_and_evaluate_remote pid=1061577) [TCN] epoch 3/3  loss=0.70331  (136.1s, 4663 batches)
# >>> [6/10] TCN finished (status=ok, 424.4s)
#
# (train_and_evaluate_remote pid=1061577) [TCN] DONE in 424.4s
# (train_and_evaluate_remote pid=1061577) [Mamba] starting on device=cuda
# (train_and_evaluate_remote pid=1061574) [TFT] epoch 2/3  loss=1.00792  (109.4s, 4663 batches)
# (train_and_evaluate_remote pid=1061574) [TFT] epoch 3/3  loss=0.75975  (122.1s, 4663 batches)
# >>> [7/10] TFT finished (status=ok, 345.4s)
#
# (train_and_evaluate_remote pid=1061574) [TFT] DONE in 345.4s
# (train_and_evaluate_remote pid=1061576) [S4D] epoch 1/3  loss=2.27438  (181.6s, 4663 batches)
# (train_and_evaluate_remote pid=1061572) [Informer] epoch 2/3  loss=0.96690  (231.4s, 4663 batches)
# (train_and_evaluate_remote pid=1061576) [S4D] epoch 2/3  loss=1.23860  (146.7s, 4663 batches)
# (train_and_evaluate_remote pid=1061572) [Informer] epoch 3/3  loss=0.74075  (195.3s, 4663 batches)
# >>> [8/10] Informer finished (status=ok, 657.9s)
#
# (train_and_evaluate_remote pid=1061572) [Informer] DONE in 657.9s
# (train_and_evaluate_remote pid=1061576) [S4D] epoch 3/3  loss=1.04330  (123.9s, 4663 batches)
# >>> [9/10] S4D finished (status=ok, 461.4s)
